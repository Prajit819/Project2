# %%
import numpy as np
import pandas as pd

# %%
h1b_data = "h1b_kaggle.csv"
h1b_df = pd.read_csv(h1b_data)

# %%
h1b_df.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
h1b_df["CASE_STATUS"].count()
# Out:
# 3002445

# %%
h1b_2015 = h1b_df[h1b_df.YEAR != 2016]
h1b_2015 = h1b_2015[h1b_2015.FULL_TIME_POSITION != 'N']
h1b_2015 = h1b_2015[h1b_2015['CASE_STATUS'] == 'CERTIFIED']

h1b_2015
# Out:
#          Unnamed: 0 CASE_STATUS  \
# 647804       647805   CERTIFIED
# 647806       647807   CERTIFIED
# 647807       647808   CERTIFIED
# 647809       647810   CERTIFIED
# 647810       647811   CERTIFIED
# 647811       647812   CERTIFIED
# 647813       647814   CERTIFIED
# 647816       647817   CERTIFIED
# 647817       647818   CERTIFIED
# 647818       647819   CERTIFIED
# 647820       647821   CERTIFIED
# 647823       647824   CERTIFIED
# 647828       647829   CERTIFIED
# 647829       647830   CERTIFIED
# 647830       647831   CERTIFIED
# 647831       647832   CERTIFIED
# 647833       647834   CERTIFIED
# 647834       647835   CERTIFIED
# 647836       647837   CERTIFIED
# 647842       647843   CERTIFIED
# 647843       647844   CERTIFIED
# 647844       647845   CERTIFIED
# 647845       647846   CERTIFIED
# 647846       647847   CERTIFIED
# 647847       647848   CERTIFIED
# 647850       647851   CERTIFIED
# 647851       647852   CERTIFIED
# 647854       647855   CERTIFIED
# ...

# %%
h1b_2015_pa = h1b_2015[h1b_2015['JOB_TITLE'] == 'PROGRAMMER ANALYST']
h1b_2015_pa
# Out:
#          Unnamed: 0 CASE_STATUS                              EMPLOYER_NAME  \
# 647834       647835   CERTIFIED                   SUNERA TECHNOLOGIES, INC
# 647851       647852   CERTIFIED                                  AIMIC INC
# 647868       647869   CERTIFIED                                  AIMIC INC
# 647995       647996   CERTIFIED          TATA CONSULTANCY SERVICES LIMITED
# 648156       648157   CERTIFIED                   SUNERA TECHNOLOGIES, INC
# 648332       648333   CERTIFIED           KIP INFORMATION TECHNOLOGIES INC
# 648411       648412   CERTIFIED                    MINDWAVE SOLUTIONS, INC
# 648731       648732   CERTIFIED                   SUNERA TECHNOLOGIES, INC
# 648734       648735   CERTIFIED                   SUNERA TECHNOLOGIES, INC
# 649918       649919   CERTIFIED                   SUNERA TECHNOLOGIES, INC
# 650403       650404   CERTIFIED                                  AIMIC INC
# ...

# %%
h1b_2015_pa["CASE_STATUS"].count()
# Out:
# 173802

# %%
h1b_2016 = h1b_df[h1b_df.YEAR != 2015]
h1b_2016
# Out:
#          Unnamed: 0          CASE_STATUS  \
# 0                 1  CERTIFIED-WITHDRAWN
# 1                 2  CERTIFIED-WITHDRAWN
# 2                 3  CERTIFIED-WITHDRAWN
# 3                 4  CERTIFIED-WITHDRAWN
# 4                 5            WITHDRAWN
# 5                 6  CERTIFIED-WITHDRAWN
# 6                 7  CERTIFIED-WITHDRAWN
# 7                 8  CERTIFIED-WITHDRAWN
# 8                 9  CERTIFIED-WITHDRAWN
# 9                10            WITHDRAWN
# 10               11  CERTIFIED-WITHDRAWN
# 11               12  CERTIFIED-WITHDRAWN
# 12               13  CERTIFIED-WITHDRAWN
# 13               14  CERTIFIED-WITHDRAWN
# 14               15  CERTIFIED-WITHDRAWN
# 15               16  CERTIFIED-WITHDRAWN
# 16               17  CERTIFIED-WITHDRAWN
# 17               18  CERTIFIED-WITHDRAWN
# 18               19            CERTIFIED
# 19               20            CERTIFIED
# 20               21  CERTIFIED-WITHDRAWN
# 21               22  CERTIFIED-WITHDRAWN
# ...

# %%
h1b_2016 = h1b_2016[h1b_2016.FULL_TIME_POSITION != 'N']
h1b_2016 = h1b_2016[h1b_2016['CASE_STATUS'] == 'CERTIFIED']
h1b_2016
# Out:
#          Unnamed: 0 CASE_STATUS  \
# 18               19   CERTIFIED
# 19               20   CERTIFIED
# 22               23   CERTIFIED
# 23               24   CERTIFIED
# 25               26   CERTIFIED
# 27               28   CERTIFIED
# 28               29   CERTIFIED
# 29               30   CERTIFIED
# 30               31   CERTIFIED
# 31               32   CERTIFIED
# 32               33   CERTIFIED
# 33               34   CERTIFIED
# 34               35   CERTIFIED
# 36               37   CERTIFIED
# 38               39   CERTIFIED
# 40               41   CERTIFIED
# 41               42   CERTIFIED
# 42               43   CERTIFIED
# 43               44   CERTIFIED
# 44               45   CERTIFIED
# 46               47   CERTIFIED
# 48               49   CERTIFIED
# 49               50   CERTIFIED
# 50               51   CERTIFIED
# 51               52   CERTIFIED
# 52               53   CERTIFIED
# 53               54   CERTIFIED
# 54               55   CERTIFIED
# ...

# %%
h1b_2016_pa = h1b_2016[h1b_2016['JOB_TITLE'] == 'PROGRAMMER ANALYST']
h1b_2016_pa
# Out:
#          Unnamed: 0 CASE_STATUS                              EMPLOYER_NAME  \
# 77844         77845   CERTIFIED                               SCUBEL, LLC.
# 77846         77847   CERTIFIED                   SATYA MARG SOLUTIONS INC
# 77847         77848   CERTIFIED                   SATYA MARG SOLUTIONS INC
# 77957         77958   CERTIFIED                            PM SYSTEMS INC.
# 77962         77963   CERTIFIED                            PM SYSTEMS INC.
# 78161         78162   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 78185         78186   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 78224         78225   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 78286         78287   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 78298         78299   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# 78314         78315   CERTIFIED      UNIVERSITY OF CALIFORNIA, LOS ANGELES
# ...

# %%
h1b_2016_pa["CASE_STATUS"].count()
# Out:
# 134110

# %%
h1b_2016_pa.to_csv('h1b_2016_pa.csv')
